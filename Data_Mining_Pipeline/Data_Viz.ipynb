# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulchandra-cu/datamining/blob/main/Data_Mining_Pipeline/Data_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Boxplot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Histogram
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Quantile Plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Quantile-Quantile (Q-Q) Plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Scatter Plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
